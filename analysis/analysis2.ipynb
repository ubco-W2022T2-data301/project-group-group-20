# %% [markdown]
# # Vaishali Raju

# %% [markdown]
# **MILESTONE 2: Load your dataset, explain it, and define your research questions**

# %% [markdown]
# ## Research question/interests
#
# Briefly describe your research question or interests here.
#
# Are there any ethical implications of credit churning to personal finance? If so, in what unethical means do they affect our personal finances?
#
# I will be exploring the ethical consequences of exploiting credit cards and banks to attain personal gains. Credit churning hasn't been deemed illegal yet, however, it is not a practice that is considered a good deed, thus they oppose several ethical rules in the society.
#
# In order to address this question, I will be cleaning, processing and removing irrelevant data to support my theory, in order to solidify the purpose of our project’s vision. Credit card churning is a common practice amongst students as they struggle to manage their finances. We intend to educate them on how these habits poorly contribute  to the moral and ethical side of the spectrum.
#
# Research Plan: My research will draw the implications and their reasonings around these practices on one’s credit score and relationship with their banks. I will be creating new columns and graphs to explain the differences between an existing and churned customer, including features that make an attrited customer stand out.

# %%
import pandas as pd
df = pd.read_csv('BankChurners.csv')
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df0 = df.drop(columns=['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'])

# %%
df0
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
df_cleaned = df0.copy().drop(['Avg_Utilization_Ratio','Avg_Open_To_Buy', 'Total_Trans_Ct', 'Total_Amt_Chng_Q4_Q1','Total_Ct_Chng_Q4_Q1','Total_Trans_Amt'], axis=1)
df_cleaned
#dropping unwanted columns
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
dropNA = df_cleaned.dropna(axis=0)
dropNA
#dropping columns that contain null values
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# **MILESTONE 3: Exploratory data analysis (EDA)**

# %% [markdown]
# My research question explores the ethical implications of credit churning.
# In order to present some interesting observations, I will be using columns Attrition Flag, Card Category, Credit limit, months on book, and revolving balance.

# %%
sns.set_theme(style="whitegrid", font_scale= 1)
sns.countplot(data=df, y = 'Attrition_Flag')
plt.title("Number of Customers by Attrition Flag")
plt.xlabel("Total number of Bank Customers")
plt.ylabel("Attrition Flag")
plt.savefig("plot1.png", dpi = 300)

# %% [markdown]
# The plot above is a simple count plot to identify the differences in the two types of bank customers: attrited and existing. Attrited customers are those that have churned and existing customers are those that are still using the card services.
# Credit card churning is only a minor issue with banks so far. Thus, the plot below suggests that roughly 25% of their customers churn.

# %%
sns.violinplot(x='Card_Category', y= 'Credit_Limit', data=df)
plt.xticks(rotation =45)
sns.set_theme(style = "darkgrid", font_scale = 1)
plt.title("Credit Scores sorted by Card category")
plt.xlabel("Card Category")
plt.ylabel("Credit Limit")
plt.savefig("plot2.png", dpi = 300)

# %% [markdown]
# Furthermore, I used card category and credit limit to show the density of data using a violin plot.
# There are 4 types of card types in credit cards: blue, sliver, platinum and gold. Credit limit is the maximum the bank allows you to spend using the credit card. If the borrower exceeds their limit, fees and other charges will be applied.
#
# It is recommended to use a maximum 30% of your credit limit to maintain your credit score.
#     The plot: the white dot is the median, the top end and bottom end represents the maximum and minimum, the width represents the frequency (density).
# There is a higher frequency of customers in blue category. Platinum and Gold customers have the highest credit limits.

# %%
sns.set_theme(style="whitegrid", font_scale= 1)
sns.boxplot(data=df, x = 'Card_Category', y = 'Months_on_book')
plt.xlabel('Card Category')
plt.ylabel('Months on book')
plt.title("Months on book by card category")
plt.xticks(rotation=45)
plt.savefig("plot3.png", dpi = 300)

# %% [markdown]
# The box plot above represents the data between months on book and card category.
# I intend to analyze how long customers remain on the books based on each category. As you can see, customers in the blue category has a higher frequency of customers in this plot as well.

# %%
sns.boxplot(y = 'Total_Revolving_Bal', x = 'Attrition_Flag', data=df)
sns.set_theme(style="darkgrid", font_scale= 1)
plt.ylabel('Total Revolving Balance')
plt.xlabel('Attrition Flag')
plt.title("Distribution of Revolving balance by Attrition Flag")
plt.show()    
plt.savefig("plot4.png", dpi = 300)

# %% [markdown]
# This box plot above explores the distribution of revolving balance between existing and attrited customer. The total Revolving balance is the amount of money the credit card holder owes to the credit card issuer. The balance carries over to the next billing cycle along with interest charged on the outstaning balance. As the plot suggests, existing customers have a higher mean revolving balance than attrited customers. However, the distrubution on revolving balance in attrited customers is much larger, data is more spread across, higher IQR, and higher variance in the numbers.

# %%
sns.countplot(y = 'Education_Level', data=df)
plt.title("Number of bank customers in each eductaion category")
sns.set_theme(style="dark", font_scale= 1)
plt.xlabel("Count of Bank customers")
plt.ylabel("Education Level")
plt.show()
plt.savefig("plot5.png", dpi = 300)

# %% [markdown]
# The count plot above displays the distribution of customer education level categories. This plot proves that there is a significant amount of high school and college students that are using credit card services, thus vulnerable to credit churning activities at present or in the future.

# %%
sns.boxplot(y = 'Months_Inactive_12_mon', x = 'Attrition_Flag', data=df)
plt.title("Months inactive by Attrition flag")
sns.set_theme(style="darkgrid", font_scale= 1)
plt.xlabel('Attrition Flag')
plt.ylabel('Months inactive')
plt.show()
plt.savefig("plot6.png", dpi = 300)

# %% [markdown]
# This box plot above intends to show the relationship between number of months inactive and attrition flag. Months inactive represents the time that has lapsed ever since the last used date of the credit card. Existing customers have a greater variation in this category, whereas attrited customers have remain inactive for a small period of time and cancel the service as soon they use the benefits and bonuses. Additionally, the attrited customer plot shows outliers in the distributions. This represents churned customers who have remained inactive for long periods of time after using their bonuses. As you can see, outliers are present only for attrited customers.

# %% [markdown]
# **MILESTONE 4: Visualizations, Analysis, and Pipeline**

# %% [markdown]
# In order to show reflections of credit churning on personal finances, I will be adding two new columns into my dataset to further analyse credit churning:
#
# - Average Credit limit
# - Credit Utilization rate (%)
#
# These two columns will be an indicator of a client's financial position.

# %%
df_cleaned["Avg_Credit_limit"]= (df_cleaned['Credit_Limit'] + df_cleaned['Months_on_book'])
df_cleaned
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# I have introduced a new column called "Average credit limit" into my dataset. It helps assess borrower's credit worthiness and help lenders make informed decisions before lending.
# It further helps the lender analyse if the borrower is eligible for higher credit limits. Students can use this column to assess their own financial status to make better spending decisions when they acquire credit cards.
# Banks can predict when their customers will churn depending on their assessment on credit worthiness.

# %%
df_cleaned["Credit_Utilization_rate"]=(df_cleaned['Total_Revolving_Bal']/df_cleaned['Credit_Limit'])*100
df_cleaned
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# Another new column named "Credit_Utilization_rate" is created to show the percentage of the borrower's total available credit that is being used currently.
# Lower the rate, better credit scores.
#
# **More importantly, increasing your credit limit can lower your credit utilization rate (%) and increase your credit scores. Higher credit limits will be an efficient source of making large purchases and provide sources for emergency funds.**

# %%
df_reshape = pd.melt(df_cleaned, id_vars = ['CLIENTNUM', 'Attrition_Flag','Income_Category','Credit_Limit','Total_Revolving_Bal'])
df_reshape
df_reshaped = df_reshape.drop(['variable','value'], axis =1)
df_reshaped
# Out:
#         CLIENTNUM     Attrition_Flag Income_Category  Credit_Limit  \
# 0       768805383  Existing Customer     $60K - $80K       12691.0
# 1       818770008  Existing Customer  Less than $40K        8256.0
# 2       713982108  Existing Customer    $80K - $120K        3418.0
# 3       769911858  Existing Customer  Less than $40K        3313.0
# 4       709106358  Existing Customer     $60K - $80K        4716.0
# ...           ...                ...             ...           ...
# 121519  772366833  Existing Customer     $40K - $60K        4003.0
# 121520  710638233  Attrited Customer     $40K - $60K        4277.0
# 121521  716506083  Attrited Customer  Less than $40K        5409.0
# 121522  717406983  Attrited Customer     $40K - $60K        5281.0
# 121523  714337233  Attrited Customer  Less than $40K       10388.0
#
#         Total_Revolving_Bal
# 0                       777
# 1                       864
# 2                         0
# 3                      2517
# ...

# %% [markdown]
# This table shows the most important columns in the dataset as a summary of the information we need to answer our research question.

# %%
df_cleaned.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %% [markdown]
# This table is an overview of the central tendency in the dataset. It provides us with a rough idea of the extremities of the dataset.

# %% [markdown]
# **METHOD CHAINING**

# %%
df_m1 = (pd.read_csv('BankChurners.csv'))\
         .drop(columns = ['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'])\
         .drop(columns = ['Avg_Utilization_Ratio','Avg_Open_To_Buy', 'Total_Trans_Ct', 'Total_Amt_Chng_Q4_Q1','Total_Ct_Chng_Q4_Q1','Total_Trans_Amt'])\
         .dropna(subset = ['Months_on_book','Total_Revolving_Bal'])\
         .reset_index(drop=True)\
         .rename(columns={"Customer_Age": "Age"}
                )
df_m1
# Out:
#        CLIENTNUM     Attrition_Flag  Age Gender  Dependent_count  \
# 0      768805383  Existing Customer   45      M                3
# 1      818770008  Existing Customer   49      F                5
# 2      713982108  Existing Customer   51      M                3
# 3      769911858  Existing Customer   40      F                4
# 4      709106358  Existing Customer   40      M                3
# ...          ...                ...  ...    ...              ...
# 10122  772366833  Existing Customer   50      M                2
# 10123  710638233  Attrited Customer   41      M                2
# 10124  716506083  Attrited Customer   44      F                1
# 10125  717406983  Attrited Customer   30      M                2
# 10126  714337233  Attrited Customer   43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# ...

# %%
df_m2 = df_m1.dropna()\
             .sort_values('Total_Revolving_Bal', ascending = False)\
             .rename(columns={"CLIENTNUM": "Client"})
df_m2
# Out:
#          Client     Attrition_Flag  Age Gender  Dependent_count  \
# 5003  771795933  Attrited Customer   49      M                4
# 507   712049208  Existing Customer   56      M                3
# 8573  812218908  Attrited Customer   46      F                2
# 2405  715499808  Existing Customer   63      F                0
# 8582  719269308  Existing Customer   49      F                2
# ...         ...                ...  ...    ...              ...
# 2940  717332733  Existing Customer   47      M                4
# 2942  708740808  Existing Customer   45      M                4
# 8168  719028783  Existing Customer   42      F                1
# 5894  718586133  Existing Customer   43      F                3
# 2251  708423933  Existing Customer   51      M                2
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# 5003         Unknown         Single         $120K +          Blue
# ...

# %%
def load_and_process(path_to_csv_file):

   df1 = (pd.read_csv('BankChurners.csv'))\
             .drop(columns = ['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'])\
             .drop(columns = ['Avg_Utilization_Ratio','Avg_Open_To_Buy','Total_Trans_Ct', 'Total_Amt_Chng_Q4_Q1','Total_Ct_Chng_Q4_Q1','Total_Trans_Amt'])\
             .dropna(subset = ['Months_on_book','Total_Revolving_Bal'])\
             .reset_index(drop=True)\
             .rename(columns={"Customer_Age": "Age"}
                    )
   df2 = (
       df1
       .dropna()\
       .sort_values('Total_Revolving_Bal', ascending = False)\
       .rename(columns={"CLIENTNUM": "Client"})
   )
       
   return df2

# %% [markdown]
# **Analysis and Conclusion**:
#
# I have further cleaned the dataset to incorporate only relevants columns. Since my research question deals with ethical implications, I intend to present data on ways we can analyse current financial positions of customers with an existing credit limit. The dataset will further elaborate to show us the various extremities in dataset where further proof is shown to justify the position of attrited customers. However, this dataset may show factors of a churned/churning customer for an existing customer. We only intend to focus on the different implications of credit churning on financial positions.
#
# I have introduced two new columns: Average Credit Limit and Credit Utilization rate. The average credit limit column shows us average credit limit for every customer based on their months on book. It helps the customer verify if their credit-worthiness and the bank to determine if they are eligible for higher credit limits. The credit utilization rate as a percentage considers the revolving balance(the amount being carried over to the next month) and the credit limit. Ideally, a lower credit utilization rate is preferred to maintain a good credit score.
#
# The graphs created above provide evidences for the differences between an existing customer and attrited customer. We intend to show how they differ from each other and what features make an attrited customer stand out of the dataset.
#
# I have **not** removed any outliers in the dataset. Removing the outliers in the numerical columns will faulter my analysis of the dataset. I want to show the outliers in the numerical columns and their relevant demographic factors to provide reasoning.

# %% [markdown]
# **MILESTONE 5: Present your Dashboard**

# %%
df_cleaned.to_csv('Data_for_Tableau.csv',index= False)
