# %% [markdown]
# # Disha Whora

# %% [markdown]
# ## Research question/interests
#
# Briefly describe your research question or interests here.
#
# To what extent does advancements in technology affect consumer behaviour and what strategies are banks imposing to tackle the issue of retention using technology?
#
# I will be focusing on the digital side of our project. Technological advancements have changed the way people bank. Previously, people had to book appointments and go to the bank. However, now the way people interact with financial institutions has changed over the years. Everything is a click away with mobile banking. Whether it is opening a new account or online shopping, consumers have evolved alongside technology and are extremely comfortable sitting at home and solving their bank problems.
# /nI will be using additional data from Pew Research Center that has provided me with a survey regarding the advancements of mobile and online banking. This dataset will allow a proper insight into consumer behaviour changing as technology becomes a vital part of our daily lives. I will also look into technological factors that banks themselves are using to retain consumers.
# /nCredit card churning is all about consumers preferring temporary periods of relationships with banks. This research question will help develop an understanding of strategies that banks use to discourage consumers from leaving their services.
#
# Analysis Plan: With the help of the additional data, I will first develop a correlation between technological advancements and consumer behaviour. Then through graphs and data visualization, I plan on answering the second part of the research question by listing out the approaches banks take to address this challenge.

# %% [markdown]
# ### Milestone 3

# %% [markdown]
# <b>Imported Libraries</b>

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('BankChurners.csv')
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df2=df.drop(columns=['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'])

# %%
df2
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df2.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
df_cleaned = df2.copy().drop(['Total_Ct_Chng_Q4_Q1','Avg_Utilization_Ratio','Total_Trans_Ct','Total_Trans_Amt','Total_Amt_Chng_Q4_Q1','Avg_Open_To_Buy','Total_Revolving_Bal'], axis=1)
df_cleaned
##dropping redundant columns (columumns not necessary for my dataset)
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
##dropping null values

# %%
df_dropnull = df_cleaned.dropna(axis=0)
df_dropnull.shape
# Out:
# (10127, 14)

# %% [markdown]
# <b>Implication:</b>
# column and row numbers have remained the same meaning there weren't any null values

# %% [markdown]
# My research question forms a connection between technological advancements and consumer psychology. To assess consumer psychology, I will be looking at factors such as education, income category and months on book. The following graphs are desribed below:
# The box plot will provide information between income category and credit limit. Some bckground information relevant to understand credit limits better:
# Credit limits are indicators that allow banks and financial institutions to depict the amount of money or credit they are willing to offer a borrower as loan. When consumers have higher credit scores, they are more favourable for loans.
# One assumption taken in this boxplot is that there is a connection between the 2 variables. Consumers with higher incomes will have better credit limits as they are more likely to pay off the debt sooner.
# As shown in the graph below, we can see that predicition we had for higher incomes having credit limits holds true. The median in the boxplot( the line cutting the box) is the highest for incomes greater than 120k. The outliers in the box plots shows credit limit for some consumers that is not appropriate for their income category. For example the category of 60k-80k has high credit limit outliers which can be due to consumers having shown bank loyalty and the bank knows and approves of the consumer's banking practices even though they have lower incomes.

# %%
ax1=sns.boxplot(x='Income_Category',y='Credit_Limit',data=df_cleaned)
ax1.set(title='Relationship between income and credit',
        xlabel='Income category',
        ylabel='Credit limit')
sns.set_theme(style="whitegrid", font_scale=1)
ax1.set_ylim(bottom=0)
plt.savefig('Graph1.png',dpi=300)

# %% [markdown]
# As I mentioned before in my research question, I will be adding data from Pew Research Center. This dataset talks about the percentage of mobile banking and internet usage for banking activities. This is important as through this we will understand the relationship between online banking and credit card churning.
# One assumption I have used is that more advancements in technology means that more people are converting to online banking.

# %%
df = {'Income_Category': ['Less than 30k','30k-49k','50k-74k','Greater than 75k'],
        '% of cell phone users who do mobile banking': [27,31,34,35]}
data=pd.DataFrame(df)
print(data)
# Out:
#     Income_Category  % of cell phone users who do mobile banking
# 0     Less than 30k                                           27
# 1           30k-49k                                           31
# 2           50k-74k                                           34
# 3  Greater than 75k                                           35

# %%
plot = data.plot.pie(y='% of cell phone users who do mobile banking', figsize=(11, 6))
plot.legend(title='Income_Category', loc='upper right', bbox_to_anchor=(1.3, 1))
plot.set(title="% of consumers pereferring online banking")
plt.savefig('Graph2.png',dpi=300)

# %% [markdown]
# As the pie chart shows that there is not a significant difference in the % of people doing online banking. However, there is still an increasing trend of people using mobile banking as income category increases. Red shaded area is a little larger than the rest.
# Since we have found that more consumers with a higher income category perform more online banking, we can draw a correlation between consumers and credit card churning based on their income category.
# The following graph shows the relationship between income category and consumer retention.Consumer retention is shown by the months on book column which shows the period of relationship with the bank.

# %%
plot3=sns.violinplot(x="Income_Category",y="Months_on_book", data=df2)
plot3.set(xlabel='Income',
        ylabel='Period of Relationship with bank', 
        title= "Relationship between length of stay of consumers and income")
plt.savefig('Graph3.png',dpi=300)

# %% [markdown]
# Advancements in online banking show that consumers have gotten more comfortable using their mobiles and internet instead of physically going to the bank. This also means it has gotten easier for consumers to access their accounts, making it easier to use the bonuses and reward programs. This shows a positive relationship between technology and credit card churning rates.

# %% [markdown]
# Some additional graphs that banks can use to help come up with retention strategies:
# The first is the relationship between credit limit and months on book. This assumes that people with a higher credit limit usally are more loyal to the bank. Another graph to be considered is the  education of consumers. This is because banks can use technology to retain consumers. They can provide consumers with user-friendly technology such as digital money management apps and security authentications for a seamless banking experience. Here, it is assumed that people with more education would be more comfortable with technology updates.Customer Age is also a variable to look at for the same cause.

# %%
plot5=sns.barplot(x="Customer_Age",y="Months_on_book",data=df_cleaned)
plot5.set(xlabel='Age',
        ylabel='Customer Status', 
        title= "Relationship between period of stay and age")
plt.savefig('Graph4.png',dpi=300)

# %%
plot6=sns.stripplot(x='Education_Level',y='Months_on_book',data=df_cleaned, jitter=True,dodge=True)
plot6.set(xlabel='Education',
        ylabel='Customer Status', 
        title= "Relationship between period of stay and education")
plt.savefig('Graph5.png',dpi=300)

# %%
plot4=sns.lineplot(x="Credit_Limit",y="Months_on_book",data=df_cleaned)
plot4.set(xlabel='Credit Limit',
        ylabel='Period of Relationship with bank', 
        title= "Relationship between length of stay of consumers and credit limit")
plt.savefig('Graph6.png',dpi=300)

# %%
sns.set_theme(style="darkgrid", font_scale= 1.5)
sns.countplot(data=df_cleaned, y = 'Education_Level')
plt.title("Education level of consumers")
plt.ylabel("Eduction Level")
plt.xlabel("# consumers")
plt.savefig('Graph7.png',dpi=300)

# %% [markdown]
# Milestone 3 has an overview of all the graphs that I explored under my research question. I also cleaned and processed the data before doing the graphs. This helped me focus on the important and relevant columns.

# %% [markdown]
# ### MILESTONE 4

# %% [markdown]
# To make the dataset look cleaner, I will be processing the data. My first task will be to add a column which will depict the average income in each category. Since the dataset still has too many columns that I am not condering as per my research question, I will be dropping the last few columns in my second step.

# %%
df2['AvgIncome'] = df2.groupby('Income_Category')['Months_on_book'].transform('mean')
df2
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df_cleaned=df2.drop(columns=['Total_Relationship_Count','Months_Inactive_12_mon','Contacts_Count_12_mon','Total_Revolving_Bal','Avg_Open_To_Buy','Total_Amt_Chng_Q4_Q1','Total_Trans_Amt','Total_Trans_Ct','Total_Ct_Chng_Q4_Q1','Avg_Utilization_Ratio'])
df_cleaned
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# Now this looks like a readable dataset with columns easy to understand! Another column that seems important to the research question is a column that categorize months on book into low, medium and high categories. This will make readers easily understand if consumers are more likely to participate in credit card churning. Lower the months on book, the consumers are more likely to paricipate in credit card churning. The fourth step to process data will be to replace "Unknown" values to become "Not Specified". Last step to process data is to deal with outliers. I will be focusing on outliers in months on book column as well as the credit limit column. One way to deal with them is finding out the median of the values.

# %%
def categorize_period_of_relationship(i):
    if i <= 12:
        return 'low'
    elif i <= 24:
        return 'medium'
    else:
        return 'high'
df_cleaned['MonthsOnBookCategory'] = df_cleaned['Months_on_book'].apply(categorize_period_of_relationship)
df_cleaned['Education_Level'] = df_cleaned['Education_Level'].replace('Unknown', 'Not specified')
df_cleaned['Marital_Status'] = df_cleaned['Marital_Status'].replace('Unknown', 'Not specified')
df_cleaned
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df_cleaned.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Credit_Limit     AvgIncome
# count  10127.000000  10127.000000
# mean    8631.953698     35.928409
# std     9088.776650      0.299436
# min     1438.300000     35.597004
# 25%     2555.000000     35.873184
# 50%     4549.000000     35.881775
# 75%    11067.500000     35.881775
# max    34516.000000     36.891334

# %%
df_cleaned['Credit_Limit'].median()
# Out:
# 4549.0

# %%
df_cleaned['Months_on_book'].median()
# Out:
# 36.0

# %%
df_reshape = pd.melt(df_cleaned, id_vars=['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category', 'Months_on_book', 'Credit_Limit', 'AvgIncome'], value_vars=['MonthsOnBookCategory'], var_name='Measurement_Type', value_name='Measurement_Value')
df_reshape
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df_merged = pd.merge(data, df_cleaned, on='Income_Category', how='outer')
df_merged
# Out:
#         Income_Category  % of cell phone users who do mobile banking  \
# 0         Less than 30k                                         27.0
# 1               30k-49k                                         31.0
# 2               50k-74k                                         34.0
# 3      Greater than 75k                                         35.0
# 4           $60K - $80K                                          NaN
# ...                 ...                                          ...
# 10126           Unknown                                          NaN
# 10127           Unknown                                          NaN
# 10128           Unknown                                          NaN
# 10129           Unknown                                          NaN
# 10130           Unknown                                          NaN
#
#          CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# ...

# %% [markdown]
# Method Chaining:

# %%
df_method1 = (pd.read_csv('BankChurners.csv')\
    .drop(columns=['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'])\
    .drop(columns=['Total_Relationship_Count','Months_Inactive_12_mon','Contacts_Count_12_mon','Total_Revolving_Bal','Avg_Open_To_Buy','Total_Amt_Chng_Q4_Q1','Total_Trans_Amt','Total_Trans_Ct','Total_Ct_Chng_Q4_Q1','Avg_Utilization_Ratio'])\
    .rename(columns={"% of cell phone users who do mobile banking": "% mobile banking"})
    
)

df_method1
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df_method2=(pd.read_csv('BankChurners.csv')\
            .query('Income_Category != "Unknown"')\
            .dropna()\
            .reset_index(drop=True)\
            .sort_values('Credit_Limit', ascending=False)
           )
df_method2
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 2314  710159658  Existing Customer            46      M                5
# 4259  709585758  Existing Customer            41      M                4
# 4189  719960133  Existing Customer            42      M                3
# 8283  710300733  Existing Customer            38      M                3
# 1550  720282558  Existing Customer            36      M                2
# ...         ...                ...           ...    ...              ...
# 5551  719074308  Existing Customer            37      F                3
# 5537  714687858  Existing Customer            49      F                1
# 5533  713578608  Existing Customer            58      M                0
# 5507  716856408  Attrited Customer            39      F                4
# 5575  812406183  Attrited Customer            45      F                4
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
def load_and_process(path_to_csv_file):
    df1=(
        pd.read_csv(path_to_csv_file)
        .drop(columns=['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'])\
        .drop(columns=['Total_Relationship_Count','Months_Inactive_12_mon','Contacts_Count_12_mon','Total_Revolving_Bal','Avg_Open_To_Buy','Total_Amt_Chng_Q4_Q1','Total_Trans_Amt','Total_Trans_Ct','Total_Ct_Chng_Q4_Q1','Avg_Utilization_Ratio'])\
        .rename(columns={"% of cell phone users who do mobile banking": "% mobile banking"})
    )
    df2=(
        df1
        .query('Income_Category != "Unknown"')\
        .dropna()\
        .reset_index(drop=True)\
        .sort_values('Credit_Limit', ascending=False)
    )
    return df2

# %% [markdown]
# <b> Analysis </b>

# %% [markdown]
# Credit card churning is a practice done by consumers where they sign up for rewards and bonuses from multiple credit cards and cancel them as soon as the annual fees begin. Technology has been an important factor in making credit card churning easier as with the help of mobile banking, one doesnt have to go to banks to sign up for rewards only to cancel the card a month later. Not only that, but through online banking, consumers can also easily compare different card offers, track their rewards and set reminders to cancel them. They can all do these various activities on their mobiles, making this way faster and easier.
# However, it is only the advancements in technology have the banks started using this to their advantage.Banks themeselves are using advanced alogrithms and machines to identify potential churners and flag them before they continue this practice.For example, if a consumer has signed up for mulitple credit cards within few months into being associated with the bank, it shows a potential churner.
# Banks have also used technological advancements in their advantage by making it harder for consumers to chrun their cards. One way this is done is by making consumers wait a certain time before they are issued another card and also limit the number of cards issued by a consumer at a time. Banks have also added filters and categories that have to be met in order to issue credit cards. For example, a premium credit card issuer must be educated, and have an income category of over 120k. These thresholds discourage churning.

# %% [markdown]
# The dataset I adopted from Kaggle provided me with all information I needed to explore my research question. I also used data from Pew Research center for the technological aspect of my research question. I merged these 2 datasets to creat a final set. I dropped uneccessary columns and any null values in the frame. I categorized the columns and added data visualisations to make the question simpler to answer. I have drawn out the following conclusions:
# More consumers that are invested in mobile banking, more they are prone to churning.
# Smaller their relationship with bank, more likely they are to churn cards. This shows that a relatively loyal consumer would not participate in credit card churning.
# As technology is advancing, banks should use technology iteself to solve this issue.

# %% [markdown]
# <b> Conclusion for M4 </b>

# %% [markdown]
# Milestone 4 dives into further processing of the data. I added extra columns to make the dataset simpler and more informative. I also performed method chaining.

# %% [markdown]
# ### MILESTONE 5

# %% [markdown]
# The cleaned and and processed data is under df_reshape:

# %%
df_reshape
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df_reshape.to_csv('my_data_for_tableau.csv', index=False)

# %%
data
# Out:
#     Income_Category  % of cell phone users who do mobile banking
# 0     Less than 30k                                           27
# 1           30k-49k                                           31
# 2           50k-74k                                           34
# 3  Greater than 75k                                           35

# %%
data.to_csv('new_data_for_tableau.csv', index=False)

# %% [markdown]
# <b> Conclusion </b>

# %% [markdown]
# More consumers that are invested in mobile banking, more they are prone to churning. Smaller their relationship with bank, more likely they are to churn cards. This shows that a relatively loyal consumer would not participate in credit card churning. As technology is advancing, banks should use technology iteself to solve this issue.
